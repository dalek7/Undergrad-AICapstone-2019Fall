# %% [markdown]
# # Neural Style Transfer
# * Created for Understanding NST (Neural Style Transfer) and Creating Art with Keras & Colab.
# * Used for a coursework (717303) at Hallym Univ.

# %%
# !pwd
# Out:
# /content

# %%
import os
#os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"]="{}".format(3) # gpu idx

# %%
from __future__ import print_function
from keras.preprocessing.image import load_img, save_img, img_to_array
import numpy as np
from scipy.optimize import fmin_l_bfgs_b
import time
import argparse
import matplotlib.pyplot as plt
from keras.applications import vgg19
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# * 아래와 같이 'AICapstone-2019Fall'을 만들었다고 가정합니다. (Google Drive)

# %%
# !ls drive/'My Drive'/'Colab Notebooks'/AICapstone-2019Fall/images
# Out:
# 20180829_115847.jpg  400x300
# 20180904_161416.jpg  Claude_Monet_Poster_Poppy_Field_at_Argenteuil_640x480.jpg
# 20181023_085206.jpg  monet_640x480.jpg
# 20181023_161555.jpg  van-gogh-starry-night.jpg
# 20181031_180133.jpg

# %%
basedir = "/content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall/"
print(basedir)
# !ls '$basedir'
# Out:
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall/
# images	NST_Keras_v1_colab.ipynb  NST_Keras_v1.ipynb  out

# %%
outDir = basedir+'/out'

import os
if not os.path.exists(outDir):
    os.makedirs(outDir)
    print('created...{}'.format(outDir))

#!ls "$outDir/../"

# %% [markdown]
# * 주의: 640x480 이미지로 변경하였습니다.

# %%
base_image_path = basedir+'images/20180904_161416.jpg'
#style_reference_image_path = basedir+'images/Claude_Monet_Poster_Poppy_Field_at_Argenteuil_640x480.jpg'#gogh_starry#
style_reference_image_path = basedir+'images/monet_640x480.jpg'#gogh_starry

print(base_image_path)
print(style_reference_image_path )
# Out:
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall/images/20180904_161416.jpg
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall/images/monet_640x480.jpg

# %% [markdown]
# ### 설정

# %%
import datetime
str_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

#result_prefix = 'generated'
#result_prefix = 'pic1'
result_prefix = 'pic_'+str_time
print(result_prefix)
# Out:
# pic_20191007_125306

# %%
iterations  = 100

# %%
content_weight = 0.025

style_weight = 1.0
#Total Variation weight.
total_variation_weight = 1.0

# %% [markdown]
# ### 그림 불러와서 테스트
# * 주의 h, w 순서

# %%
img1 = load_img(base_image_path)
print(img1.size)
img2 = load_img(style_reference_image_path, target_size=(480,640))
print(img2.size)
# Out:
# (640, 480)
# (640, 480)

# %%
imgplot = plt.imshow(img1)

# %%
imgplot = plt.imshow(img2)

# %% [markdown]
# ### The weights of the different loss components

# %% [markdown]
# ### Dimensions of the generated picture

# %%
width, height = load_img(base_image_path).size
print(width, height)
# Out:
# 640 480

# %%
img_nrows = height
img_ncols = width#int(width * img_nrows / height)
print(img_nrows, img_ncols)
# Out:
# 480 640

# %% [markdown]
# ### Util functions

# %%
#  to open, resize and format pictures into appropriate tensors
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %%
def deprocess_image(x):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((3, img_nrows, img_ncols))
        x = x.transpose((1, 2, 0))
    else:
        x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
# get tensor representations of our images
base_image = K.variable(preprocess_image(base_image_path))
style_reference_image = K.variable(preprocess_image(style_reference_image_path))

# %%
K.image_data_format()
# Out:
# 'channels_last'

# %%
# this will contain our generated image
if K.image_data_format() == 'channels_first':
    combination_image = K.placeholder((1, 3, img_nrows, img_ncols))
else:
    combination_image = K.placeholder((1, img_nrows, img_ncols, 3))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
# combine the 3 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image,
                              combination_image], axis=0)

# %% [markdown]
# ### build the VGG19 network

# %%
# build the VGG19 network with our 3 images as input
# the model will be loaded with pre-trained ImageNet weights
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet', include_top=False)
print('Model loaded.')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# Model loaded.

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])

# %% [markdown]
# ### Compute the neural style loss

# %%
# first we need to define 4 util functions
# the gram matrix of an image tensor (feature-wise outer product)

def gram_matrix(x):
    assert K.ndim(x) == 3
    if K.image_data_format() == 'channels_first':
        features = K.batch_flatten(x)
    else:
        features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %%
# the "style loss" is designed to maintain
# the style of the reference image in the generated image.
# It is based on the gram matrices (which capture style) of
# feature maps from the style reference image
# and from the generated image
def style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# %%
# an auxiliary loss function
# designed to maintain the "content" of the
# base image in the generated image


def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
# the 3rd loss function, total variation loss,
# designed to keep the generated image locally coherent

def total_variation_loss(x):
    assert K.ndim(x) == 4
    if K.image_data_format() == 'channels_first':
        a = K.square(
            x[:, :, :img_nrows - 1, :img_ncols - 1] - x[:, :, 1:, :img_ncols - 1])
        b = K.square(
            x[:, :, :img_nrows - 1, :img_ncols - 1] - x[:, :, :img_nrows - 1, 1:])
    else:
        a = K.square(
            x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
        b = K.square(
            x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %% [markdown]
# ### Combine these loss functions into a single scalar

# %%
loss = K.variable(0.0)
layer_features = outputs_dict['block5_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(base_image_features,
                                            combination_features)

# %%
feature_layers = ['block1_conv1', 'block2_conv1',
                  'block3_conv1', 'block4_conv1',
                  'block5_conv1']

# %%
for layer_name in feature_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss = loss + (style_weight / len(feature_layers)) * sl

# %%
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
# get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
outputs = [loss]
if isinstance(grads, (list, tuple)):
    outputs += grads
else:
    outputs.append(grads)

# %%
f_outputs = K.function([combination_image], outputs)

# %%
def eval_loss_and_grads(x):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((1, 3, img_nrows, img_ncols))
    else:
        x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# %%
# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.


class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values


evaluator = Evaluator()

# %%
print(outDir)
# Out:
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out

# %%
# !ls "$outDir"
# Out:
# pic_20191007_112926_at_iteration_0.png
# pic_20191007_112926_at_iteration_1.png
# pic_20191007_112926_at_iteration_2.png
# pic_20191007_113206_at_iteration_0.png
# pic_20191007_113206_at_iteration_10.png
# pic_20191007_113206_at_iteration_11.png
# pic_20191007_113206_at_iteration_12.png
# pic_20191007_113206_at_iteration_13.png
# pic_20191007_113206_at_iteration_14.png
# pic_20191007_113206_at_iteration_15.png
# pic_20191007_113206_at_iteration_16.png
# pic_20191007_113206_at_iteration_17.png
# pic_20191007_113206_at_iteration_18.png
# pic_20191007_113206_at_iteration_19.png
# pic_20191007_113206_at_iteration_1.png
# pic_20191007_113206_at_iteration_20.png
# pic_20191007_113206_at_iteration_21.png
# pic_20191007_113206_at_iteration_22.png
# pic_20191007_113206_at_iteration_23.png
# pic_20191007_113206_at_iteration_24.png
# pic_20191007_113206_at_iteration_25.png
# pic_20191007_113206_at_iteration_26.png
# pic_20191007_113206_at_iteration_27.png
# pic_20191007_113206_at_iteration_28.png
# pic_20191007_113206_at_iteration_29.png
# pic_20191007_113206_at_iteration_2.png
# pic_20191007_113206_at_iteration_30.png
# pic_20191007_113206_at_iteration_31.png
# pic_20191007_113206_at_iteration_32.png
# pic_20191007_113206_at_iteration_33.png
# pic_20191007_113206_at_iteration_34.png
# pic_20191007_113206_at_iteration_35.png
# pic_20191007_113206_at_iteration_36.png
# pic_20191007_113206_at_iteration_37.png
# pic_20191007_113206_at_iteration_38.png
# pic_20191007_113206_at_iteration_39.png
# pic_20191007_113206_at_iteration_3.png
# pic_20191007_113206_at_iteration_40.png
# pic_20191007_113206_at_iteration_41.png
# pic_20191007_113206_at_iteration_42.png
# pic_20191007_113206_at_iteration_43.png
# pic_20191007_113206_at_iteration_44.png
# pic_20191007_113206_at_iteration_45.png
# pic_20191007_113206_at_iteration_46.png
# pic_20191007_113206_at_iteration_47.png
# pic_20191007_113206_at_iteration_48.png
# pic_20191007_113206_at_iteration_49.png
# pic_20191007_113206_at_iteration_4.png
# pic_20191007_113206_at_iteration_50.png
# pic_20191007_113206_at_iteration_51.png
# pic_20191007_113206_at_iteration_52.png
# pic_20191007_113206_at_iteration_53.png
# pic_20191007_113206_at_iteration_54.png
# pic_20191007_113206_at_iteration_55.png
# pic_20191007_113206_at_iteration_56.png
# pic_20191007_113206_at_iteration_57.png
# pic_20191007_113206_at_iteration_58.png
# pic_20191007_113206_at_iteration_59.png
# pic_20191007_113206_at_iteration_5.png
# pic_20191007_113206_at_iteration_60.png
# pic_20191007_113206_at_iteration_61.png
# pic_20191007_113206_at_iteration_62.png
# pic_20191007_113206_at_iteration_63.png
# pic_20191007_113206_at_iteration_64.png
# pic_20191007_113206_at_iteration_65.png
# pic_20191007_113206_at_iteration_66.png
# pic_20191007_113206_at_iteration_67.png
# pic_20191007_113206_at_iteration_68.png
# pic_20191007_113206_at_iteration_69.png
# pic_20191007_113206_at_iteration_6.png
# pic_20191007_113206_at_iteration_70.png
# pic_20191007_113206_at_iteration_71.png
# pic_20191007_113206_at_iteration_72.png
# pic_20191007_113206_at_iteration_73.png
# pic_20191007_113206_at_iteration_74.png
# pic_20191007_113206_at_iteration_75.png
# pic_20191007_113206_at_iteration_76.png
# pic_20191007_113206_at_iteration_77.png
# pic_20191007_113206_at_iteration_78.png
# pic_20191007_113206_at_iteration_79.png
# pic_20191007_113206_at_iteration_7.png
# pic_20191007_113206_at_iteration_80.png
# pic_20191007_113206_at_iteration_81.png
# pic_20191007_113206_at_iteration_82.png
# pic_20191007_113206_at_iteration_83.png
# pic_20191007_113206_at_iteration_84.png
# pic_20191007_113206_at_iteration_85.png
# pic_20191007_113206_at_iteration_86.png
# pic_20191007_113206_at_iteration_87.png
# pic_20191007_113206_at_iteration_88.png
# pic_20191007_113206_at_iteration_89.png
# pic_20191007_113206_at_iteration_8.png
# pic_20191007_113206_at_iteration_90.png
# pic_20191007_113206_at_iteration_91.png
# pic_20191007_113206_at_iteration_92.png
# pic_20191007_113206_at_iteration_93.png
# pic_20191007_113206_at_iteration_94.png
# pic_20191007_113206_at_iteration_95.png
# pic_20191007_113206_at_iteration_96.png
# pic_20191007_113206_at_iteration_97.png
# pic_20191007_113206_at_iteration_98.png
# pic_20191007_113206_at_iteration_99.png
# pic_20191007_113206_at_iteration_9.png

# %%
# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # save current generated image
    img = deprocess_image(x.copy())
    fname = outDir + '/' + result_prefix + '_at_iteration_%d.png' % i
    #fname = '/content/drive/' + result_prefix + '_at_iteration_%d.png' % i

    #!ls "/content/drive/My Drive"

    #fname = '/content/drive/My Drive/Colab Notebooks/out/'+ result_prefix + '_at_iteration_%d.png' % i
    
    print(fname)
    save_img(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 1461398500.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_0.png
# Iteration 0 completed in 28s
# Start of iteration 1
# Current loss value: 765691200.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_1.png
# Iteration 1 completed in 22s
# Start of iteration 2
# Current loss value: 620932540.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_2.png
# Iteration 2 completed in 22s
# Start of iteration 3
# Current loss value: 560241100.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_3.png
# Iteration 3 completed in 23s
# Start of iteration 4
# Current loss value: 524622000.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_4.png
# Iteration 4 completed in 22s
# Start of iteration 5
# Current loss value: 500386560.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_5.png
# Iteration 5 completed in 22s
# Start of iteration 6
# Current loss value: 479038100.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_6.png
# Iteration 6 completed in 22s
# Start of iteration 7
# Current loss value: 466111040.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_7.png
# Iteration 7 completed in 22s
# Start of iteration 8
# Current loss value: 456304450.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_8.png
# Iteration 8 completed in 22s
# Start of iteration 9
# Current loss value: 448334600.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_9.png
# Iteration 9 completed in 21s
# Start of iteration 10
# Current loss value: 438978400.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_10.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_10.png
# Iteration 10 completed in 22s
# Start of iteration 11
# Current loss value: 431605570.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_11.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_11.png
# Iteration 11 completed in 22s
# Start of iteration 12
# Current loss value: 425487360.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_12.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_12.png
# Iteration 12 completed in 22s
# Start of iteration 13
# Current loss value: 420697950.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_13.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_13.png
# Iteration 13 completed in 21s
# Start of iteration 14
# Current loss value: 415192100.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_14.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_14.png
# Iteration 14 completed in 22s
# Start of iteration 15
# Current loss value: 410476450.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_15.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_15.png
# Iteration 15 completed in 22s
# Start of iteration 16
# Current loss value: 404331200.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_16.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_16.png
# Iteration 16 completed in 22s
# Start of iteration 17
# Current loss value: 399883400.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_17.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_17.png
# Iteration 17 completed in 22s
# Start of iteration 18
# Current loss value: 396094500.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_18.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_18.png
# Iteration 18 completed in 22s
# Start of iteration 19
# Current loss value: 392407360.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_19.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_19.png
# Iteration 19 completed in 22s
# Start of iteration 20
# Current loss value: 389052300.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_20.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_20.png
# Iteration 20 completed in 22s
# Start of iteration 21
# Current loss value: 386434370.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_21.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_21.png
# Iteration 21 completed in 22s
# Start of iteration 22
# Current loss value: 383902080.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_22.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_22.png
# Iteration 22 completed in 22s
# Start of iteration 23
# Current loss value: 381532600.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_23.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_23.png
# Iteration 23 completed in 22s
# Start of iteration 24
# Current loss value: 379393020.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_24.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_24.png
# Iteration 24 completed in 22s
# Start of iteration 25
# Current loss value: 377404480.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_25.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_25.png
# Iteration 25 completed in 22s
# Start of iteration 26
# Current loss value: 375348450.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_26.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_26.png
# Iteration 26 completed in 22s
# Start of iteration 27
# Current loss value: 373462430.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_27.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_27.png
# Iteration 27 completed in 22s
# Start of iteration 28
# Current loss value: 371799100.0
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_28.png
# Image saved as /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration
# pic_20191007_125306_at_iteration_41.png
# pic_20191007_125306_at_iteration_42.png
# pic_20191007_125306_at_iteration_43.png
# pic_20191007_125306_at_iteration_44.png
# pic_20191007_125306_at_iteration_45.png
# pic_20191007_125306_at_iteration_46.png
# pic_20191007_125306_at_iteration_47.png
# pic_20191007_125306_at_iteration_48.png
# pic_20191007_125306_at_iteration_49.png
# pic_20191007_125306_at_iteration_4.png
# pic_20191007_125306_at_iteration_50.png
# pic_20191007_125306_at_iteration_51.png
# pic_20191007_125306_at_iteration_52.png
# pic_20191007_125306_at_iteration_53.png
# pic_20191007_125306_at_iteration_54.png
# pic_20191007_125306_at_iteration_55.png
# pic_20191007_125306_at_iteration_56.png
# pic_20191007_125306_at_iteration_57.png
# pic_20191007_125306_at_iteration_58.png
# pic_20191007_125306_at_iteration_59.png
# pic_20191007_125306_at_iteration_5.png
# pic_20191007_125306_at_iteration_60.png
# pic_20191007_125306_at_iteration_61.png
# pic_20191007_125306_at_iteration_62.png
# pic_20191007_125306_at_iteration_63.png
# pic_20191007_125306_at_iteration_64.png
# pic_20191007_125306_at_iteration_65.png
# pic_20191007_125306_at_iteration_66.png
# pic_20191007_125306_at_iteration_67.png
# pic_20191007_125306_at_iteration_68.png
# pic_20191007_125306_at_iteration_69.png
# pic_20191007_125306_at_iteration_6.png
# pic_20191007_125306_at_iteration_70.png
# pic_20191007_125306_at_iteration_71.png
# pic_20191007_125306_at_iteration_72.png
# pic_20191007_125306_at_iteration_73.png
# pic_20191007_125306_at_iteration_74.png
# pic_20191007_125306_at_iteration_75.png
# pic_20191007_125306_at_iteration_76.png
# pic_20191007_125306_at_iteration_77.png
# pic_20191007_125306_at_iteration_78.png
# pic_20191007_125306_at_iteration_79.png
# pic_20191007_125306_at_iteration_7.png
# pic_20191007_125306_at_iteration_80.png
# pic_20191007_125306_at_iteration_81.png
# pic_20191007_125306_at_iteration_82.png
# pic_20191007_125306_at_iteration_83.png
# pic_20191007_125306_at_iteration_84.png
# pic_20191007_125306_at_iteration_85.png
# pic_20191007_125306_at_iteration_86.png
# pic_20191007_125306_at_iteration_87.png
# pic_20191007_125306_at_iteration_88.png
# pic_20191007_125306_at_iteration_89.png
# pic_20191007_125306_at_iteration_8.png
# pic_20191007_125306_at_iteration_90.png
# pic_20191007_125306_at_iteration_91.png
# pic_20191007_125306_at_iteration_92.png
# pic_20191007_125306_at_iteration_93.png
# pic_20191007_125306_at_iteration_94.png
# pic_20191007_125306_at_iteration_95.png
# pic_20191007_125306_at_iteration_96.png
# pic_20191007_125306_at_iteration_97.png
# pic_20191007_125306_at_iteration_98.png
# pic_20191007_125306_at_iteration_99.png
# pic_20191007_125306_at_iteration_9.png

# %%
fnameout = outDir + '/' + result_prefix + '_at_iteration_%d.png' % (iterations-1)
imgout = load_img(fnameout, target_size=(300,400))
imgplot = plt.imshow(imgout)
print(fnameout)
# Out:
# /content/drive/My Drive/Colab Notebooks/AICapstone-2019Fall//out/pic_20191007_125306_at_iteration_99.png

# %% [markdown]
# ### References

# %% [markdown]
# [1] Neural style transfer with Keras. https://keras.io/examples/neural_style_transfer/
